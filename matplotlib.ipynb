# %% [markdown]
# <a href="https://colab.research.google.com/github/mumtehaartun/pandas/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
 import matplotlib.pyplot as plt
 y = np.random.randn(100)
 x = np.cumsum(np.random.rand(100))
 plt.plot(x,y,'r-')

# %%
a=np.random.rand(100)
b=np.cumsum(a)
b
# Out:
# array([ 0.76593223,  1.02766165,  1.59857414,  1.97525663,  2.79596613,
#         3.10819209,  4.09982825,  4.75588028,  5.3007781 ,  5.36929751,
#         5.52371563,  5.66296087,  6.66173089,  7.34813346,  7.87740594,
#         8.50433663,  8.67171607,  9.35352551,  9.43028483, 10.14041108,
#        11.0313339 , 11.87646391, 12.04879686, 13.03632301, 13.31306943,
#        14.08807424, 14.95386855, 14.97641234, 15.22333949, 15.46061719,
#        16.00699419, 16.50418448, 17.44721154, 18.06037534, 18.56491507,
#        19.25336475, 20.15654832, 20.51445296, 21.22420655, 22.10141337,
#        22.4419539 , 22.91712897, 23.04071478, 23.89353384, 24.09714661,
#        24.29798562, 24.7145951 , 25.5234815 , 25.56939534, 25.67932083,
#        26.40944685, 27.20918451, 27.58232794, 27.86483473, 28.48308177,
#        29.29986594, 30.103403  , 30.27354713, 30.62338574, 31.37327944,
#        32.04565413, 32.60119497, 32.80163445, 33.27874166, 34.18751655,
# ...

# %%
a
# Out:
# array([0.76593223, 0.26172943, 0.57091249, 0.37668248, 0.8207095 ,
#        0.31222596, 0.99163615, 0.65605203, 0.54489781, 0.06851941,
#        0.15441813, 0.13924523, 0.99877002, 0.68640257, 0.52927248,
#        0.62693069, 0.16737944, 0.68180944, 0.07675932, 0.71012625,
#        0.89092282, 0.84513001, 0.17233295, 0.98752615, 0.27674642,
#        0.77500481, 0.86579431, 0.02254379, 0.24692715, 0.2372777 ,
#        0.546377  , 0.49719029, 0.94302706, 0.6131638 , 0.50453973,
#        0.68844968, 0.90318357, 0.35790464, 0.70975359, 0.87720681,
#        0.34054053, 0.47517507, 0.12358581, 0.85281907, 0.20361277,
#        0.20083901, 0.41660948, 0.80888641, 0.04591384, 0.10992549,
#        0.73012602, 0.79973766, 0.37314343, 0.28250679, 0.61824704,
#        0.81678417, 0.80353706, 0.17014413, 0.34983862, 0.7498937 ,
#        0.67237468, 0.55554084, 0.20043948, 0.47710721, 0.9087749 ,
#        0.46568863, 0.16061488, 0.74996533, 0.75853458, 0.06983238,
# ...

# %%
a[0]+a[1]
# Out:
# 1.0276616546311232

# %%
 plt.plot(x,y,alpha = 0.5, color = '#FF7F00', \
 label = 'Line Label', linestyle = '-.', \
 linewidth = 3, marker = 'o', markeredgecolor = '#000000', \
 markeredgewidth = 2, markerfacecolor = '#FF7F00', \
 markersize=30)

# %%
import matplotlib.pyplot as plt

agg_filter = None
alpha = None
animated = False
...
y = np.random.randn(100)
x = np.cumsum(np.random.rand(100))
h, = plt.plot(x, y)
plt.setp(h, alpha=0.5)
plt.setp(h, color='purple')
plt.setp(h, linestyle='--')

plt.show()
